# %% [markdown]
# # Timeseries classification from scratch
#
# **Author:** [hfawaz](https://github.com/hfawaz/)<br>
# **Date created:** 2020/07/21<br>
# **Last modified:** 2021/07/16<br>
# **Description:** Training a timeseries classifier from scratch on the FordA dataset from the UCR/UEA archive.

# %% [markdown]
# ## Introduction
#
# This example shows how to do timeseries classification from scratch, starting from raw
# CSV timeseries files on disk. We demonstrate the workflow on the FordA dataset from the
# [UCR/UEA archive](https://www.cs.ucr.edu/%7Eeamonn/time_series_data_2018/).

# %% [markdown]
# ## Setup

# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2023-07-19 03:44:58.913966: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-19 03:44:59.028018: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# ## Load the data: the FordA dataset
#
# ### Dataset description
#
# The dataset we are using here is called FordA.
# The data comes from the UCR archive.
# The dataset contains 3601 training instances and another 1320 testing instances.
# Each timeseries corresponds to a measurement of engine noise captured by a motor sensor.
# For this task, the goal is to automatically detect the presence of a specific issue with
# the engine. The problem is a balanced binary classification task. The full description of
# this dataset can be found [here](http://www.j-wichard.de/publications/FordPaper.pdf).
#
#
# ```
# $PATH/FordA$ tree -s
# [       4096]  .
# ├── [    7364408]  FordA_TEST.tsv
# └── [   20094049]  FordA_TRAIN.tsv
# ```
#
#
#
# ### Read the TSV data
#
# We will use the `FordA_TRAIN` file for training and the
# `FordA_TEST` file for testing. The simplicity of this dataset
# allows us to demonstrate effectively how to use ConvNets for timeseries classification.
# In this file, the first column corresponds to the label.

# %%
def readucr(filename):
    data = np.loadtxt(filename, delimiter="\t")
    y = data[:, 0]
    x = data[:, 1:]
    return x, y.astype(int)


root_url = "https://raw.githubusercontent.com/hfawaz/cd-diagram/master/FordA/"

x_train, y_train = readucr(root_url + "FordA_TRAIN.tsv")
x_test, y_test = readucr(root_url + "FordA_TEST.tsv")

print(f'Train data: x_train: {x_train.shape}, y_train: {y_train.shape}')
print(f'Test data: x_test {x_test.shape}, {y_test.shape}')
# Out:
# Train data: x_train: (3601, 500), y_train: (3601,)
# Test data: x_test (1320, 500), (1320,)

# %% [markdown]
# ## Visualize the data
#
# Here we visualize one timeseries example for each class in the dataset.

# %%
classes = np.unique(np.concatenate((y_train, y_test), axis=0))


start_sample_numbers=1700
end_interval=5

for idx in range(start_sample_numbers,start_sample_numbers+end_interval):
    print(f'idx: {idx}')    
    plt.figure().set_figheight(1)
    for c in classes:
        c_x_train = x_train[y_train == c]
        print(f'    class {c} with c_x_train.shape {c_x_train.shape}')
        plt.plot(c_x_train[idx], label="class " + str(c))


    plt.legend(loc="best")
    plt.title(f'train time series for sample number {idx}')
    plt.show()
    plt.close()
# Out:
# idx: 1700
#     class -1 with c_x_train.shape (1846, 500)
#     class 1 with c_x_train.shape (1755, 500)
# idx: 1701
#     class -1 with c_x_train.shape (1846, 500)
#     class 1 with c_x_train.shape (1755, 500)
# idx: 1702
#     class -1 with c_x_train.shape (1846, 500)
#     class 1 with c_x_train.shape (1755, 500)
# idx: 1703
#     class -1 with c_x_train.shape (1846, 500)
#     class 1 with c_x_train.shape (1755, 500)
# idx: 1704
#     class -1 with c_x_train.shape (1846, 500)
#     class 1 with c_x_train.shape (1755, 500)

# %% [markdown]
# ## Standardize the data
#
# Our timeseries are already in a single length (500). However, their values are
# usually in various ranges. This is not ideal for a neural network;
# in general we should seek to make the input values normalized.
# For this specific dataset, the data is already z-normalized: each timeseries sample
# has a mean equal to zero and a standard deviation equal to one. This type of
# normalization is very common for timeseries classification problems, see
# [Bagnall et al. (2016)](https://link.springer.com/article/10.1007/s10618-016-0483-9).
#
# Note that the timeseries data used here are univariate, meaning we only have one channel
# per timeseries example.
# We will therefore transform the timeseries into a multivariate one with one channel
# using a simple reshaping via numpy.
# This will allow us to construct a model that is easily applicable to multivariate time
# series.

# %%
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))


print(f'x_train.shape: {x_train.shape}, x_test.shape {x_test.shape}')
# Out:
# x_train.shape: (3601, 500, 1), x_test.shape (1320, 500, 1)

# %% [markdown]
# Finally, in order to use `sparse_categorical_crossentropy`, we will have to count
# the number of classes beforehand.

# %%
num_classes = len(np.unique(y_train))
print(f'y_train.shape: {y_train.shape}')
print(f'num_classes: {num_classes}')
# Out:
# y_train.shape: (3601,)
# num_classes: 2

# %% [markdown]
# Now we shuffle the training set because we will be using the `validation_split` option
# later when training.

# %%
idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]

# %% [markdown]
# Standardize the labels to positive integers.
# The expected labels will then be 0 and 1.

# %%
y_train[y_train == -1] = 0
y_test[y_test == -1] = 0

# %% [markdown]
# ## Build a model
#
# We build a Fully Convolutional Neural Network originally proposed in
# [this paper](https://arxiv.org/abs/1611.06455).
# The implementation is based on the TF 2 version provided
# [here](https://github.com/hfawaz/dl-4-tsc/).
# The following hyperparameters (kernel_size, filters, the usage of BatchNorm) were found
# via random search using [KerasTuner](https://github.com/keras-team/keras-tuner).

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)
    print(f'input_layer: {input_layer}')

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)
    print(f'output_layer: {output_layer}')

    return keras.models.Model(inputs=input_layer, outputs=output_layer)

input_shape=x_train.shape[1:]
print(f'input_shape: {input_shape}')
model = make_model(input_shape=input_shape)
keras.utils.plot_model(model, show_shapes=True)
# Out:
# input_shape: (500, 1)
# input_layer: KerasTensor(type_spec=TensorSpec(shape=(None, 500, 1), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'")
# 2023-07-19 03:45:03.122380: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-19 03:45:03.154078: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-19 03:45:03.154308: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-19 03:45:03.156248: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-19 03:45:03.158475: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-19 03:45:03.158686: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-19 03:45:03.158822: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-19 03:45:03.822791: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-19 03:45:03.823229: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-19 03:45:03.823510: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-19 03:45:03.823750: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6218 MB memory:  -> device: 0, name: NVIDIA RTX A2000 8GB Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# output_layer: KerasTensor(type_spec=TensorSpec(shape=(None, 2), dtype=tf.float32, name=None), name='dense/Softmax:0', description="created by layer 'dense'")

# %% [markdown]
# ## Train the model

# %%
# epochs = 2
# epochs = 10
# epochs = 50
epochs = 100
# epochs = 300
# epochs = 500

# batch_size = 16
# batch_size = 32
batch_size = 64

callbacks = [
    keras.callbacks.ModelCheckpoint("best_model.h5", save_best_only=True, monitor="val_loss"),
    keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001),
    #keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)

# Model training APIs (methods for compile, fit, evaluate)
# https://keras.io/api/models/model_training_apis/
# Out:
# Epoch 1/100
# 45/45 [==============================] - 3s 19ms/step - loss: 0.2539 - sparse_categorical_accuracy: 0.8938 - val_loss: 0.2546 - val_sparse_categorical_accuracy: 0.8821 - lr: 0.0010
# Epoch 2/100
# 45/45 [==============================] - 1s 14ms/step - loss: 0.2450 - sparse_categorical_accuracy: 0.9000 - val_loss: 0.3096 - val_sparse_categorical_accuracy: 0.8530 - lr: 0.0010
# Epoch 3/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.2422 - sparse_categorical_accuracy: 0.9042 - val_loss: 0.2694 - val_sparse_categorical_accuracy: 0.8724 - lr: 0.0010
# Epoch 4/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.2425 - sparse_categorical_accuracy: 0.9045 - val_loss: 0.2318 - val_sparse_categorical_accuracy: 0.9140 - lr: 0.0010
# Epoch 5/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.2300 - sparse_categorical_accuracy: 0.9087 - val_loss: 0.2321 - val_sparse_categorical_accuracy: 0.8960 - lr: 0.0010
# Epoch 6/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.2194 - sparse_categorical_accuracy: 0.9101 - val_loss: 0.2896 - val_sparse_categorical_accuracy: 0.8807 - lr: 0.0010
# Epoch 7/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.2243 - sparse_categorical_accuracy: 0.9139 - val_loss: 0.6967 - val_sparse_categorical_accuracy: 0.7434 - lr: 0.0010
# Epoch 8/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.2220 - sparse_categorical_accuracy: 0.9108 - val_loss: 0.2491 - val_sparse_categorical_accuracy: 0.8918 - lr: 0.0010
# Epoch 9/100
# 45/45 [==============================] - 1s 14ms/step - loss: 0.2172 - sparse_categorical_accuracy: 0.9139 - val_loss: 0.7721 - val_sparse_categorical_accuracy: 0.7351 - lr: 0.0010
# Epoch 10/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.2256 - sparse_categorical_accuracy: 0.9104 - val_loss: 0.4380 - val_sparse_categorical_accuracy: 0.7684 - lr: 0.0010
# Epoch 11/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.2277 - sparse_categorical_accuracy: 0.9045 - val_loss: 2.5026 - val_sparse_categorical_accuracy: 0.6006 - lr: 0.0010
# Epoch 12/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.2222 - sparse_categorical_accuracy: 0.9135 - val_loss: 2.7491 - val_sparse_categorical_accuracy: 0.6546 - lr: 0.0010
# Epoch 13/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.2138 - sparse_categorical_accuracy: 0.9181 - val_loss: 1.4324 - val_sparse_categorical_accuracy: 0.7087 - lr: 0.0010
# Epoch 14/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.2168 - sparse_categorical_accuracy: 0.9128 - val_loss: 1.8061 - val_sparse_categorical_accuracy: 0.5798 - lr: 0.0010
# Epoch 15/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.2116 - sparse_categorical_accuracy: 0.9163 - val_loss: 0.9759 - val_sparse_categorical_accuracy: 0.6685 - lr: 0.0010
# Epoch 16/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.2276 - sparse_categorical_accuracy: 0.9049 - val_loss: 0.3349 - val_sparse_categorical_accuracy: 0.8405 - lr: 0.0010
# Epoch 17/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.2140 - sparse_categorical_accuracy: 0.9128 - val_loss: 0.2563 - val_sparse_categorical_accuracy: 0.8863 - lr: 0.0010
# Epoch 18/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.2160 - sparse_categorical_accuracy: 0.9174 - val_loss: 0.5070 - val_sparse_categorical_accuracy: 0.7781 - lr: 0.0010
# Epoch 19/100
# 45/45 [==============================] - 1s 14ms/step - loss: 0.2065 - sparse_categorical_accuracy: 0.9187 - val_loss: 0.3959 - val_sparse_categorical_accuracy: 0.8155 - lr: 0.0010
# Epoch 20/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.2103 - sparse_categorical_accuracy: 0.9160 - val_loss: 0.4603 - val_sparse_categorical_accuracy: 0.7601 - lr: 0.0010
# Epoch 21/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.2077 - sparse_categorical_accuracy: 0.9153 - val_loss: 0.4436 - val_sparse_categorical_accuracy: 0.7698 - lr: 0.0010
# Epoch 22/100
# 45/45 [==============================] - 1s 16ms/step - loss: 0.2016 - sparse_categorical_accuracy: 0.9177 - val_loss: 0.2016 - val_sparse_categorical_accuracy: 0.9251 - lr: 0.0010
# Epoch 23/100
# 45/45 [==============================] - 1s 16ms/step - loss: 0.2034 - sparse_categorical_accuracy: 0.9174 - val_loss: 2.3191 - val_sparse_categorical_accuracy: 0.5409 - lr: 0.0010
# Epoch 24/100
# 45/45 [==============================] - 1s 16ms/step - loss: 0.2081 - sparse_categorical_accuracy: 0.9177 - val_loss: 0.8040 - val_sparse_categorical_accuracy: 0.6588 - lr: 0.0010
# Epoch 25/100
# 45/45 [==============================] - 1s 17ms/step - loss: 0.1876 - sparse_categorical_accuracy: 0.9302 - val_loss: 0.2268 - val_sparse_categorical_accuracy: 0.9085 - lr: 0.0010
# Epoch 26/100
# 45/45 [==============================] - 1s 16ms/step - loss: 0.1858 - sparse_categorical_accuracy: 0.9271 - val_loss: 0.5021 - val_sparse_categorical_accuracy: 0.7767 - lr: 0.0010
# Epoch 27/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.1876 - sparse_categorical_accuracy: 0.9299 - val_loss: 0.2084 - val_sparse_categorical_accuracy: 0.9140 - lr: 0.0010
# Epoch 28/100
# 45/45 [==============================] - 1s 16ms/step - loss: 0.1673 - sparse_categorical_accuracy: 0.9431 - val_loss: 0.2757 - val_sparse_categorical_accuracy: 0.8599 - lr: 0.0010
# Epoch 29/100
# 45/45 [==============================] - 1s 16ms/step - loss: 0.1638 - sparse_categorical_accuracy: 0.9389 - val_loss: 0.4081 - val_sparse_categorical_accuracy: 0.8044 - lr: 0.0010
# Epoch 30/100
# 45/45 [==============================] - 1s 16ms/step - loss: 0.1580 - sparse_categorical_accuracy: 0.9427 - val_loss: 0.1869 - val_sparse_categorical_accuracy: 0.9265 - lr: 0.0010
# Epoch 31/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.1565 - sparse_categorical_accuracy: 0.9431 - val_loss: 0.3861 - val_sparse_categorical_accuracy: 0.8225 - lr: 0.0010
# Epoch 32/100
# 45/45 [==============================] - 1s 18ms/step - loss: 0.1424 - sparse_categorical_accuracy: 0.9521 - val_loss: 1.3213 - val_sparse_categorical_accuracy: 0.7101 - lr: 0.0010
# Epoch 33/100
# 45/45 [==============================] - 1s 16ms/step - loss: 0.2010 - sparse_categorical_accuracy: 0.9194 - val_loss: 0.8123 - val_sparse_categorical_accuracy: 0.7004 - lr: 0.0010
# Epoch 34/100
# 45/45 [==============================] - 1s 16ms/step - loss: 0.1740 - sparse_categorical_accuracy: 0.9344 - val_loss: 0.1516 - val_sparse_categorical_accuracy: 0.9459 - lr: 0.0010
# Epoch 35/100
# 45/45 [==============================] - 1s 14ms/step - loss: 0.1397 - sparse_categorical_accuracy: 0.9531 - val_loss: 0.6087 - val_sparse_categorical_accuracy: 0.7503 - lr: 0.0010
# Epoch 36/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.1275 - sparse_categorical_accuracy: 0.9583 - val_loss: 0.2519 - val_sparse_categorical_accuracy: 0.8793 - lr: 0.0010
# Epoch 37/100
# 45/45 [==============================] - 1s 16ms/step - loss: 0.1329 - sparse_categorical_accuracy: 0.9559 - val_loss: 0.5840 - val_sparse_categorical_accuracy: 0.7351 - lr: 0.0010
# Epoch 38/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.1199 - sparse_categorical_accuracy: 0.9622 - val_loss: 0.6306 - val_sparse_categorical_accuracy: 0.7060 - lr: 0.0010
# Epoch 39/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.1228 - sparse_categorical_accuracy: 0.9576 - val_loss: 0.5867 - val_sparse_categorical_accuracy: 0.7517 - lr: 0.0010
# Epoch 40/100
# 45/45 [==============================] - 1s 16ms/step - loss: 0.1273 - sparse_categorical_accuracy: 0.9580 - val_loss: 0.1972 - val_sparse_categorical_accuracy: 0.9196 - lr: 0.0010
# Epoch 41/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.1459 - sparse_categorical_accuracy: 0.9476 - val_loss: 0.7288 - val_sparse_categorical_accuracy: 0.7212 - lr: 0.0010
# Epoch 42/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.1390 - sparse_categorical_accuracy: 0.9542 - val_loss: 0.5101 - val_sparse_categorical_accuracy: 0.7767 - lr: 0.0010
# Epoch 43/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.1146 - sparse_categorical_accuracy: 0.9632 - val_loss: 1.3207 - val_sparse_categorical_accuracy: 0.6963 - lr: 0.0010
# Epoch 44/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.1164 - sparse_categorical_accuracy: 0.9625 - val_loss: 0.2568 - val_sparse_categorical_accuracy: 0.8849 - lr: 0.0010
# Epoch 45/100
# 45/45 [==============================] - 1s 14ms/step - loss: 0.1160 - sparse_categorical_accuracy: 0.9608 - val_loss: 0.6381 - val_sparse_categorical_accuracy: 0.7656 - lr: 0.0010
# Epoch 46/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.1091 - sparse_categorical_accuracy: 0.9639 - val_loss: 1.8619 - val_sparse_categorical_accuracy: 0.6865 - lr: 0.0010
# Epoch 47/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.1070 - sparse_categorical_accuracy: 0.9667 - val_loss: 0.1836 - val_sparse_categorical_accuracy: 0.9168 - lr: 0.0010
# Epoch 48/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.1102 - sparse_categorical_accuracy: 0.9660 - val_loss: 0.1280 - val_sparse_categorical_accuracy: 0.9598 - lr: 0.0010
# Epoch 49/100
# 45/45 [==============================] - 1s 14ms/step - loss: 0.1106 - sparse_categorical_accuracy: 0.9639 - val_loss: 0.3925 - val_sparse_categorical_accuracy: 0.8322 - lr: 0.0010
# Epoch 50/100
# 45/45 [==============================] - 1s 14ms/step - loss: 0.1284 - sparse_categorical_accuracy: 0.9535 - val_loss: 0.5536 - val_sparse_categorical_accuracy: 0.7462 - lr: 0.0010
# Epoch 51/100
# 45/45 [==============================] - 1s 14ms/step - loss: 0.1077 - sparse_categorical_accuracy: 0.9635 - val_loss: 0.7545 - val_sparse_categorical_accuracy: 0.7559 - lr: 0.0010
# Epoch 52/100
# 45/45 [==============================] - 1s 14ms/step - loss: 0.1115 - sparse_categorical_accuracy: 0.9608 - val_loss: 0.3726 - val_sparse_categorical_accuracy: 0.8308 - lr: 0.0010
# Epoch 53/100
# 45/45 [==============================] - 1s 14ms/step - loss: 0.1136 - sparse_categorical_accuracy: 0.9611 - val_loss: 1.2987 - val_sparse_categorical_accuracy: 0.6338 - lr: 0.0010
# Epoch 54/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.1071 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.3426 - val_sparse_categorical_accuracy: 0.8474 - lr: 0.0010
# Epoch 55/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.1035 - sparse_categorical_accuracy: 0.9660 - val_loss: 0.2055 - val_sparse_categorical_accuracy: 0.9209 - lr: 0.0010
# Epoch 56/100
# 45/45 [==============================] - 1s 16ms/step - loss: 0.1010 - sparse_categorical_accuracy: 0.9663 - val_loss: 0.1261 - val_sparse_categorical_accuracy: 0.9653 - lr: 0.0010
# Epoch 57/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.1097 - sparse_categorical_accuracy: 0.9611 - val_loss: 1.6436 - val_sparse_categorical_accuracy: 0.6782 - lr: 0.0010
# Epoch 58/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.1032 - sparse_categorical_accuracy: 0.9667 - val_loss: 2.0130 - val_sparse_categorical_accuracy: 0.7323 - lr: 0.0010
# Epoch 59/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.0973 - sparse_categorical_accuracy: 0.9698 - val_loss: 2.2724 - val_sparse_categorical_accuracy: 0.6380 - lr: 0.0010
# Epoch 60/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.1035 - sparse_categorical_accuracy: 0.9677 - val_loss: 2.6611 - val_sparse_categorical_accuracy: 0.6574 - lr: 0.0010
# Epoch 61/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.1079 - sparse_categorical_accuracy: 0.9601 - val_loss: 4.4063 - val_sparse_categorical_accuracy: 0.5173 - lr: 0.0010
# Epoch 62/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.0980 - sparse_categorical_accuracy: 0.9691 - val_loss: 1.1373 - val_sparse_categorical_accuracy: 0.7087 - lr: 0.0010
# Epoch 63/100
# 45/45 [==============================] - 1s 16ms/step - loss: 0.0997 - sparse_categorical_accuracy: 0.9688 - val_loss: 0.1073 - val_sparse_categorical_accuracy: 0.9626 - lr: 0.0010
# Epoch 64/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.1002 - sparse_categorical_accuracy: 0.9667 - val_loss: 0.7371 - val_sparse_categorical_accuracy: 0.7337 - lr: 0.0010
# Epoch 65/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.0977 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.4134 - val_sparse_categorical_accuracy: 0.8225 - lr: 0.0010
# Epoch 66/100
# 45/45 [==============================] - 1s 14ms/step - loss: 0.1017 - sparse_categorical_accuracy: 0.9639 - val_loss: 2.9870 - val_sparse_categorical_accuracy: 0.6449 - lr: 0.0010
# Epoch 67/100
# 45/45 [==============================] - 1s 14ms/step - loss: 0.0978 - sparse_categorical_accuracy: 0.9688 - val_loss: 2.0740 - val_sparse_categorical_accuracy: 0.6505 - lr: 0.0010
# Epoch 68/100
# 45/45 [==============================] - 1s 14ms/step - loss: 0.1090 - sparse_categorical_accuracy: 0.9611 - val_loss: 1.0173 - val_sparse_categorical_accuracy: 0.7101 - lr: 0.0010
# Epoch 69/100
# 45/45 [==============================] - 1s 14ms/step - loss: 0.0971 - sparse_categorical_accuracy: 0.9646 - val_loss: 2.0846 - val_sparse_categorical_accuracy: 0.5631 - lr: 0.0010
# Epoch 70/100
# 45/45 [==============================] - 1s 16ms/step - loss: 0.0950 - sparse_categorical_accuracy: 0.9688 - val_loss: 1.0643 - val_sparse_categorical_accuracy: 0.7476 - lr: 0.0010
# Epoch 71/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.0920 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.2048 - val_sparse_categorical_accuracy: 0.9168 - lr: 0.0010
# Epoch 72/100
# 45/45 [==============================] - 1s 14ms/step - loss: 0.0975 - sparse_categorical_accuracy: 0.9656 - val_loss: 0.1693 - val_sparse_categorical_accuracy: 0.9196 - lr: 0.0010
# Epoch 73/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.1009 - sparse_categorical_accuracy: 0.9667 - val_loss: 0.7999 - val_sparse_categorical_accuracy: 0.7712 - lr: 0.0010
# Epoch 74/100
# 45/45 [==============================] - 1s 14ms/step - loss: 0.0967 - sparse_categorical_accuracy: 0.9677 - val_loss: 2.0479 - val_sparse_categorical_accuracy: 0.7060 - lr: 0.0010
# Epoch 75/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.0988 - sparse_categorical_accuracy: 0.9649 - val_loss: 1.6685 - val_sparse_categorical_accuracy: 0.7226 - lr: 0.0010
# Epoch 76/100
# 45/45 [==============================] - 1s 14ms/step - loss: 0.0996 - sparse_categorical_accuracy: 0.9642 - val_loss: 2.4976 - val_sparse_categorical_accuracy: 0.7226 - lr: 0.0010
# Epoch 77/100
# 45/45 [==============================] - 1s 14ms/step - loss: 0.0970 - sparse_categorical_accuracy: 0.9670 - val_loss: 1.4613 - val_sparse_categorical_accuracy: 0.7295 - lr: 0.0010
# Epoch 78/100
# 45/45 [==============================] - 1s 14ms/step - loss: 0.0897 - sparse_categorical_accuracy: 0.9688 - val_loss: 2.9170 - val_sparse_categorical_accuracy: 0.6325 - lr: 0.0010
# Epoch 79/100
# 45/45 [==============================] - 1s 14ms/step - loss: 0.0996 - sparse_categorical_accuracy: 0.9635 - val_loss: 1.3782 - val_sparse_categorical_accuracy: 0.7406 - lr: 0.0010
# Epoch 80/100
# 45/45 [==============================] - 1s 14ms/step - loss: 0.0945 - sparse_categorical_accuracy: 0.9642 - val_loss: 0.1895 - val_sparse_categorical_accuracy: 0.9126 - lr: 0.0010
# Epoch 81/100
# 45/45 [==============================] - 1s 14ms/step - loss: 0.0905 - sparse_categorical_accuracy: 0.9670 - val_loss: 1.7784 - val_sparse_categorical_accuracy: 0.7143 - lr: 0.0010
# Epoch 82/100
# 45/45 [==============================] - 1s 14ms/step - loss: 0.0973 - sparse_categorical_accuracy: 0.9681 - val_loss: 1.2196 - val_sparse_categorical_accuracy: 0.7462 - lr: 0.0010
# Epoch 83/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.0909 - sparse_categorical_accuracy: 0.9684 - val_loss: 0.1958 - val_sparse_categorical_accuracy: 0.9182 - lr: 0.0010
# Epoch 84/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.0900 - sparse_categorical_accuracy: 0.9698 - val_loss: 0.1114 - val_sparse_categorical_accuracy: 0.9612 - lr: 5.0000e-04
# Epoch 85/100
# 45/45 [==============================] - 1s 16ms/step - loss: 0.0837 - sparse_categorical_accuracy: 0.9712 - val_loss: 0.0954 - val_sparse_categorical_accuracy: 0.9723 - lr: 5.0000e-04
# Epoch 86/100
# 45/45 [==============================] - 1s 19ms/step - loss: 0.0844 - sparse_categorical_accuracy: 0.9698 - val_loss: 0.0936 - val_sparse_categorical_accuracy: 0.9639 - lr: 5.0000e-04
# Epoch 87/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.0854 - sparse_categorical_accuracy: 0.9712 - val_loss: 0.0853 - val_sparse_categorical_accuracy: 0.9709 - lr: 5.0000e-04
# Epoch 88/100
# 45/45 [==============================] - 1s 14ms/step - loss: 0.0777 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0904 - val_sparse_categorical_accuracy: 0.9667 - lr: 5.0000e-04
# Epoch 89/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.0760 - sparse_categorical_accuracy: 0.9733 - val_loss: 0.1016 - val_sparse_categorical_accuracy: 0.9667 - lr: 5.0000e-04
# Epoch 90/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.0808 - sparse_categorical_accuracy: 0.9719 - val_loss: 0.0890 - val_sparse_categorical_accuracy: 0.9709 - lr: 5.0000e-04
# Epoch 91/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.0818 - sparse_categorical_accuracy: 0.9719 - val_loss: 0.0902 - val_sparse_categorical_accuracy: 0.9723 - lr: 5.0000e-04
# Epoch 92/100
# 45/45 [==============================] - 1s 16ms/step - loss: 0.0780 - sparse_categorical_accuracy: 0.9760 - val_loss: 0.0897 - val_sparse_categorical_accuracy: 0.9653 - lr: 5.0000e-04
# Epoch 93/100
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0869 - sparse_categorical_accuracy: 0.9712 - val_loss: 0.0990 - val_sparse_categorical_accuracy: 0.9667 - lr: 5.0000e-04
# Epoch 94/100
# 45/45 [==============================] - 1s 16ms/step - loss: 0.0812 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.1905 - val_sparse_categorical_accuracy: 0.9196 - lr: 5.0000e-04
# Epoch 95/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.0834 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.4434 - val_sparse_categorical_accuracy: 0.8183 - lr: 5.0000e-04
# Epoch 96/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.0861 - sparse_categorical_accuracy: 0.9701 - val_loss: 0.1012 - val_sparse_categorical_accuracy: 0.9667 - lr: 5.0000e-04
# Epoch 97/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.0723 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.1663 - val_sparse_categorical_accuracy: 0.9237 - lr: 5.0000e-04
# Epoch 98/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.0784 - sparse_categorical_accuracy: 0.9719 - val_loss: 0.2226 - val_sparse_categorical_accuracy: 0.9015 - lr: 5.0000e-04
# Epoch 99/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.0743 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.1217 - val_sparse_categorical_accuracy: 0.9417 - lr: 5.0000e-04
# Epoch 100/100
# 45/45 [==============================] - 1s 15ms/step - loss: 0.0776 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.1272 - val_sparse_categorical_accuracy: 0.9487 - lr: 5.0000e-04

# %% [markdown]
# ## Evaluate model on test data

# %%
model = keras.models.load_model("best_model.h5")
test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0984 - sparse_categorical_accuracy: 0.9667
# Test accuracy 0.9666666388511658
# Test loss 0.09842848032712936

# %% [markdown]
# ## Plot the model's training and validation loss

# %%
metric = "sparse_categorical_accuracy"

print(f'history.params: {history.params}' )
print(f'history.history.keys(): {history.history.keys()}')

plt.figure()

plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.plot(history.history['lr'])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()
# Out:
# history.params: {'verbose': 1, 'epochs': 100, 'steps': 45}
# history.history.keys(): dict_keys(['loss', 'sparse_categorical_accuracy', 'val_loss', 'val_sparse_categorical_accuracy', 'lr'])

# %% [markdown]
# We can see how the training accuracy reaches almost 0.95 after 100 epochs.
# However, by observing the validation accuracy we can see how the network still needs
# training until it reaches almost 0.97 for both the validation and the training accuracy
# after 200 epochs. Beyond the 200th epoch, if we continue on training, the validation
# accuracy will start decreasing while the training accuracy will continue on increasing:
# the model starts overfitting.
