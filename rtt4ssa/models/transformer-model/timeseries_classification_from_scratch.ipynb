# %% [markdown]
# # Timeseries classification from scratch
#
# **Author:** [hfawaz](https://github.com/hfawaz/)<br>
# **Replication:** [mxochicale](https://github.com/mxochicale/)<br>
# **Date created:** 2020/07/21<br>
# **Description:** Training a timeseries classifier from scratch on the FordA dataset from the UCR/UEA archive.
#
#
# **Logs:**
# * MX: Fri 21 Jul 21:45:20 BST 2023 # For ploting. I tried plot_history(history) but needs some refactor and maybe add it in utils. https://gist.github.com/whyboris/91ee793ddc92cf1e824978cf31bb790c
# * MX: Sun 23 Jul 11:35:21 BST 2023 # Add plot and dependencies for confusion matrix

# %% [markdown]
# ## Introduction
#
# This example shows how to do timeseries classification from scratch, starting from raw
# CSV timeseries files on disk. We demonstrate the workflow on the FordA dataset from the
# [UCR/UEA archive](https://www.cs.ucr.edu/%7Eeamonn/time_series_data_2018/).

# %% [markdown]
# ## Setup

# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import sklearn.metrics
import itertools
# Out:
# 2023-07-24 09:35:56.801679: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-24 09:35:57.028115: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# ## Load the data: the FordA dataset
#
# ### Dataset description
#
# The dataset we are using here is called FordA.
# The data comes from the UCR archive.
# The dataset contains 3601 training instances and another 1320 testing instances.
# Each timeseries corresponds to a measurement of engine noise captured by a motor sensor.
# For this task, the goal is to automatically detect the presence of a specific issue with
# the engine. The problem is a balanced binary classification task. The full description of
# this dataset can be found [here](http://www.j-wichard.de/publications/FordPaper.pdf).
#
#
# ```
# $PATH/FordA$ tree -s
# [       4096]  .
# ├── [    7364408]  FordA_TEST.tsv
# └── [   20094049]  FordA_TRAIN.tsv
# ```
#
#
#
# ### Read the TSV data
#
# We will use the `FordA_TRAIN` file for training and the
# `FordA_TEST` file for testing. The simplicity of this dataset
# allows us to demonstrate effectively how to use ConvNets for timeseries classification.
# In this file, the first column corresponds to the label.

# %%
def readucr(filename):
    data = np.loadtxt(filename, delimiter="\t")
    y = data[:, 0]
    x = data[:, 1:]
    return x, y.astype(int)


root_url = "https://raw.githubusercontent.com/hfawaz/cd-diagram/master/FordA/"

x_train, y_train = readucr(root_url + "FordA_TRAIN.tsv")
x_test, y_test = readucr(root_url + "FordA_TEST.tsv")

print(f'Train data: x_train: {x_train.shape}, y_train: {y_train.shape}')
print(f'Test data: x_test {x_test.shape}, {y_test.shape}')
# Out:
# Train data: x_train: (3601, 500), y_train: (3601,)
# Test data: x_test (1320, 500), (1320,)

# %%
## Reducing train and test data size

lenght_of_time_series=500 # Original size # 500
train_size=3600 # Original size # 3601
print(type(x_train))
print(x_train.shape)
x_train = np.resize(x_train, (train_size,lenght_of_time_series))
print(x_train.shape)

print(y_train.shape)
y_train = np.resize(y_train, (train_size,))
print(y_train.shape)

test_size = 1300 # Original size #1320
print(type(x_test))
print(x_test.shape)
x_test = np.resize(x_test, (test_size,lenght_of_time_series))
print(x_test.shape)

print(y_test.shape)
y_test = np.resize(y_test, (test_size,))
print(y_test.shape)
# Out:
# <class 'numpy.ndarray'>
# (3601, 500)
# (3600, 500)
# (3601,)
# (3600,)
# <class 'numpy.ndarray'>
# (1320, 500)
# (1300, 500)
# (1320,)
# (1300,)

# %% [markdown]
# ## Visualize the data
#
# Here we visualize one timeseries example for each class in the dataset.

# %%
classes = np.unique(np.concatenate((y_train, y_test), axis=0))

start_sample_numbers=300
end_interval=2

for idx in range(start_sample_numbers,start_sample_numbers+end_interval):
    print(f'idx: {idx}')    
    
    for c in classes:
        print(f'c: {c}')
        # print(f'    y_train == c; {y_train == c}')
        c_x_train = x_train[y_train == c]
        print(f'    class {c} with c_x_train.shape {c_x_train.shape}')
        plt.figure().set_figheight(1)
        plt.plot(c_x_train[idx], label="class " + str(c))
        plt.legend(loc="best")
        plt.title(f'train time series for sample number {idx}')
        plt.show()
        plt.close()
    plt.close()
# Out:
# idx: 300
# c: -1
#     class -1 with c_x_train.shape (1845, 500)
# c: 1
#     class 1 with c_x_train.shape (1755, 500)
# idx: 301
# c: -1
#     class -1 with c_x_train.shape (1845, 500)
# c: 1
#     class 1 with c_x_train.shape (1755, 500)

# %% [markdown]
# ## Standardize the data
#
# Our timeseries are already in a single length (500). However, their values are
# usually in various ranges. This is not ideal for a neural network;
# in general we should seek to make the input values normalized.
# For this specific dataset, the data is already z-normalized: each timeseries sample
# has a mean equal to zero and a standard deviation equal to one. This type of
# normalization is very common for timeseries classification problems, see
# [Bagnall et al. (2016)](https://link.springer.com/article/10.1007/s10618-016-0483-9).
#
# Note that the timeseries data used here are univariate, meaning we only have one channel
# per timeseries example.
# We will therefore transform the timeseries into a multivariate one with one channel
# using a simple reshaping via numpy.
# This will allow us to construct a model that is easily applicable to multivariate time
# series.

# %%
print(f'x_train.shape: {x_train.shape}, x_test.shape {x_test.shape}')

x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))


print(f'x_train.shape: {x_train.shape}, x_test.shape {x_test.shape}')
# Out:
# x_train.shape: (3600, 500), x_test.shape (1300, 500)
# x_train.shape: (3600, 500, 1), x_test.shape (1300, 500, 1)

# %% [markdown]
# Finally, in order to use `sparse_categorical_crossentropy`, we will have to count
# the number of classes beforehand.

# %%
num_classes = len(np.unique(y_train))
print(f'y_train.shape: {y_train.shape}')
print(f'num_classes: {num_classes}')
# Out:
# y_train.shape: (3600,)
# num_classes: 2

# %% [markdown]
# Now we shuffle the training set because we will be using the `validation_split` option
# later when training.

# %%
idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]

# %% [markdown]
# Standardize the labels to positive integers.
# The expected labels will then be 0 and 1.

# %%
y_train[y_train == -1] = 0
y_test[y_test == -1] = 0

# %% [markdown]
# ## Build a model
#
# We build a Fully Convolutional Neural Network originally proposed in
# [this paper](https://arxiv.org/abs/1611.06455).
# The implementation is based on the TF 2 version provided
# [here](https://github.com/hfawaz/dl-4-tsc/).
# The following hyperparameters (kernel_size, filters, the usage of BatchNorm) were found
# via random search using [KerasTuner](https://github.com/keras-team/keras-tuner).

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)
    print(f'input_layer: {input_layer}')

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)
    print(f'output_layer: {output_layer}')

    return keras.models.Model(inputs=input_layer, outputs=output_layer)

# %%
input_shape=x_train.shape[1:]
print(f'input_shape: {input_shape}')
model = make_model(input_shape=input_shape)
keras.utils.plot_model(model, show_shapes=True)
# Out:
# input_shape: (500, 1)
# input_layer: KerasTensor(type_spec=TensorSpec(shape=(None, 500, 1), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'")
# 2023-07-24 09:36:29.601861: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-24 09:36:29.650646: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-24 09:36:29.651026: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-24 09:36:29.654132: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-24 09:36:29.656124: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-24 09:36:29.656500: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-24 09:36:29.656718: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-24 09:36:30.335032: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-24 09:36:30.335381: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-24 09:36:30.335610: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-24 09:36:30.335793: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6218 MB memory:  -> device: 0, name: NVIDIA RTX A2000 8GB Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# output_layer: KerasTensor(type_spec=TensorSpec(shape=(None, 2), dtype=tf.float32, name=None), name='dense/Softmax:0', description="created by layer 'dense'")

# %% [markdown]
# ## Train the model

# %%
# epochs = 2
# epochs = 10
epochs = 50
# epochs = 100
# epochs = 300
# epochs = 500

# batch_size = 16
# batch_size = 32
batch_size = 64

callbacks = [
    keras.callbacks.ModelCheckpoint("best_model.h5", save_best_only=True, monitor="val_loss"),
    keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001),
    #keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)

# fit network
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)

# Model training APIs (methods for compile, fit, evaluate)
# https://keras.io/api/models/model_training_apis/
# Out:
# Epoch 1/50
# 2023-07-24 09:37:42.393375: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8800
# 2023-07-24 09:37:44.037852: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-07-24 09:37:44.039720: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f2252eb4530 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-07-24 09:37:44.039769: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA RTX A2000 8GB Laptop GPU, Compute Capability 8.6
# 2023-07-24 09:37:44.049618: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-07-24 09:37:44.320565: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 45/45 [==============================] - 10s 29ms/step - loss: 0.6054 - sparse_categorical_accuracy: 0.6552 - val_loss: 0.7035 - val_sparse_categorical_accuracy: 0.4778 - lr: 0.0010
# Epoch 2/50
# 45/45 [==============================] - 1s 18ms/step - loss: 0.5020 - sparse_categorical_accuracy: 0.7556 - val_loss: 0.7691 - val_sparse_categorical_accuracy: 0.4778 - lr: 0.0010
# Epoch 3/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.4505 - sparse_categorical_accuracy: 0.7712 - val_loss: 0.7375 - val_sparse_categorical_accuracy: 0.4778 - lr: 0.0010
# Epoch 4/50
# 45/45 [==============================] - 1s 16ms/step - loss: 0.4274 - sparse_categorical_accuracy: 0.7833 - val_loss: 0.8064 - val_sparse_categorical_accuracy: 0.4778 - lr: 0.0010
# Epoch 5/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.4085 - sparse_categorical_accuracy: 0.7979 - val_loss: 0.7212 - val_sparse_categorical_accuracy: 0.4806 - lr: 0.0010
# Epoch 6/50
# 45/45 [==============================] - 1s 19ms/step - loss: 0.4238 - sparse_categorical_accuracy: 0.7906 - val_loss: 0.7071 - val_sparse_categorical_accuracy: 0.4347 - lr: 0.0010
# Epoch 7/50
# 45/45 [==============================] - 1s 16ms/step - loss: 0.3964 - sparse_categorical_accuracy: 0.8010 - val_loss: 0.7384 - val_sparse_categorical_accuracy: 0.5222 - lr: 0.0010
# Epoch 8/50
# 45/45 [==============================] - 1s 16ms/step - loss: 0.3983 - sparse_categorical_accuracy: 0.8028 - val_loss: 0.7057 - val_sparse_categorical_accuracy: 0.5542 - lr: 0.0010
# Epoch 9/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.3904 - sparse_categorical_accuracy: 0.8073 - val_loss: 0.6664 - val_sparse_categorical_accuracy: 0.5403 - lr: 0.0010
# Epoch 10/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.3825 - sparse_categorical_accuracy: 0.8115 - val_loss: 0.5197 - val_sparse_categorical_accuracy: 0.7944 - lr: 0.0010
# Epoch 11/50
# 45/45 [==============================] - 1s 18ms/step - loss: 0.3877 - sparse_categorical_accuracy: 0.8111 - val_loss: 0.8033 - val_sparse_categorical_accuracy: 0.5292 - lr: 0.0010
# Epoch 12/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.3794 - sparse_categorical_accuracy: 0.8174 - val_loss: 0.7162 - val_sparse_categorical_accuracy: 0.5931 - lr: 0.0010
# Epoch 13/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.3692 - sparse_categorical_accuracy: 0.8299 - val_loss: 0.4387 - val_sparse_categorical_accuracy: 0.7889 - lr: 0.0010
# Epoch 14/50
# 45/45 [==============================] - 1s 16ms/step - loss: 0.3631 - sparse_categorical_accuracy: 0.8281 - val_loss: 0.6801 - val_sparse_categorical_accuracy: 0.5736 - lr: 0.0010
# Epoch 15/50
# 45/45 [==============================] - 1s 19ms/step - loss: 0.3612 - sparse_categorical_accuracy: 0.8240 - val_loss: 1.3532 - val_sparse_categorical_accuracy: 0.5222 - lr: 0.0010
# Epoch 16/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.3618 - sparse_categorical_accuracy: 0.8278 - val_loss: 0.4940 - val_sparse_categorical_accuracy: 0.7306 - lr: 0.0010
# Epoch 17/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.3521 - sparse_categorical_accuracy: 0.8365 - val_loss: 0.5361 - val_sparse_categorical_accuracy: 0.7000 - lr: 0.0010
# Epoch 18/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.3584 - sparse_categorical_accuracy: 0.8236 - val_loss: 0.9019 - val_sparse_categorical_accuracy: 0.5486 - lr: 0.0010
# Epoch 19/50
# 45/45 [==============================] - 1s 16ms/step - loss: 0.3475 - sparse_categorical_accuracy: 0.8410 - val_loss: 0.4569 - val_sparse_categorical_accuracy: 0.7431 - lr: 0.0010
# Epoch 20/50
# 45/45 [==============================] - 1s 18ms/step - loss: 0.3394 - sparse_categorical_accuracy: 0.8448 - val_loss: 0.3306 - val_sparse_categorical_accuracy: 0.8667 - lr: 0.0010
# Epoch 21/50
# 45/45 [==============================] - 1s 18ms/step - loss: 0.3275 - sparse_categorical_accuracy: 0.8542 - val_loss: 0.3896 - val_sparse_categorical_accuracy: 0.8069 - lr: 0.0010
# Epoch 22/50
# 45/45 [==============================] - 1s 16ms/step - loss: 0.3328 - sparse_categorical_accuracy: 0.8514 - val_loss: 1.0269 - val_sparse_categorical_accuracy: 0.5278 - lr: 0.0010
# Epoch 23/50
# 45/45 [==============================] - 1s 16ms/step - loss: 0.3190 - sparse_categorical_accuracy: 0.8594 - val_loss: 0.3808 - val_sparse_categorical_accuracy: 0.8028 - lr: 0.0010
# Epoch 24/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.3179 - sparse_categorical_accuracy: 0.8601 - val_loss: 0.3503 - val_sparse_categorical_accuracy: 0.8139 - lr: 0.0010
# Epoch 25/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.3350 - sparse_categorical_accuracy: 0.8458 - val_loss: 0.3525 - val_sparse_categorical_accuracy: 0.8500 - lr: 0.0010
# Epoch 26/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.3206 - sparse_categorical_accuracy: 0.8601 - val_loss: 0.6367 - val_sparse_categorical_accuracy: 0.6889 - lr: 0.0010
# Epoch 27/50
# 45/45 [==============================] - 1s 20ms/step - loss: 0.3162 - sparse_categorical_accuracy: 0.8642 - val_loss: 0.3172 - val_sparse_categorical_accuracy: 0.8639 - lr: 0.0010
# Epoch 28/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.3013 - sparse_categorical_accuracy: 0.8778 - val_loss: 0.5751 - val_sparse_categorical_accuracy: 0.6847 - lr: 0.0010
# Epoch 29/50
# 45/45 [==============================] - 1s 18ms/step - loss: 0.2975 - sparse_categorical_accuracy: 0.8712 - val_loss: 0.3766 - val_sparse_categorical_accuracy: 0.7667 - lr: 0.0010
# Epoch 30/50
# 45/45 [==============================] - 1s 16ms/step - loss: 0.3275 - sparse_categorical_accuracy: 0.8469 - val_loss: 0.3188 - val_sparse_categorical_accuracy: 0.8597 - lr: 0.0010
# Epoch 31/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.3119 - sparse_categorical_accuracy: 0.8615 - val_loss: 0.2950 - val_sparse_categorical_accuracy: 0.8819 - lr: 0.0010
# Epoch 32/50
# 45/45 [==============================] - 1s 16ms/step - loss: 0.2955 - sparse_categorical_accuracy: 0.8753 - val_loss: 0.5514 - val_sparse_categorical_accuracy: 0.6944 - lr: 0.0010
# Epoch 33/50
# 45/45 [==============================] - 1s 16ms/step - loss: 0.2842 - sparse_categorical_accuracy: 0.8799 - val_loss: 0.5129 - val_sparse_categorical_accuracy: 0.6819 - lr: 0.0010
# Epoch 34/50
# 45/45 [==============================] - 1s 16ms/step - loss: 0.2903 - sparse_categorical_accuracy: 0.8722 - val_loss: 0.8719 - val_sparse_categorical_accuracy: 0.6208 - lr: 0.0010
# Epoch 35/50
# 45/45 [==============================] - 1s 16ms/step - loss: 0.2861 - sparse_categorical_accuracy: 0.8792 - val_loss: 0.4890 - val_sparse_categorical_accuracy: 0.7264 - lr: 0.0010
# Epoch 36/50
# 45/45 [==============================] - 1s 16ms/step - loss: 0.2831 - sparse_categorical_accuracy: 0.8806 - val_loss: 0.3059 - val_sparse_categorical_accuracy: 0.8597 - lr: 0.0010
# Epoch 37/50
# 45/45 [==============================] - 1s 16ms/step - loss: 0.2968 - sparse_categorical_accuracy: 0.8632 - val_loss: 2.2189 - val_sparse_categorical_accuracy: 0.5694 - lr: 0.0010
# Epoch 38/50
# 45/45 [==============================] - 1s 16ms/step - loss: 0.2739 - sparse_categorical_accuracy: 0.8889 - val_loss: 0.4018 - val_sparse_categorical_accuracy: 0.7514 - lr: 0.0010
# Epoch 39/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.2813 - sparse_categorical_accuracy: 0.8840 - val_loss: 0.4370 - val_sparse_categorical_accuracy: 0.7486 - lr: 0.0010
# Epoch 40/50
# 45/45 [==============================] - 1s 19ms/step - loss: 0.2785 - sparse_categorical_accuracy: 0.8889 - val_loss: 0.2901 - val_sparse_categorical_accuracy: 0.8722 - lr: 0.0010
# Epoch 41/50
# 45/45 [==============================] - 1s 18ms/step - loss: 0.2619 - sparse_categorical_accuracy: 0.8896 - val_loss: 0.2736 - val_sparse_categorical_accuracy: 0.9125 - lr: 0.0010
# Epoch 42/50
# 45/45 [==============================] - 1s 18ms/step - loss: 0.2893 - sparse_categorical_accuracy: 0.8753 - val_loss: 0.6198 - val_sparse_categorical_accuracy: 0.6861 - lr: 0.0010
# Epoch 43/50
# 45/45 [==============================] - 1s 18ms/step - loss: 0.2651 - sparse_categorical_accuracy: 0.8944 - val_loss: 0.4232 - val_sparse_categorical_accuracy: 0.7806 - lr: 0.0010
# Epoch 44/50
# 45/45 [==============================] - 1s 16ms/step - loss: 0.2754 - sparse_categorical_accuracy: 0.8799 - val_loss: 0.3676 - val_sparse_categorical_accuracy: 0.7986 - lr: 0.0010
# Epoch 45/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.2490 - sparse_categorical_accuracy: 0.8993 - val_loss: 0.3680 - val_sparse_categorical_accuracy: 0.7917 - lr: 0.0010
# Epoch 46/50
# 45/45 [==============================] - 1s 17ms/step - loss: 0.2550 - sparse_categorical_accuracy: 0.8924 - val_loss: 0.2600 - val_sparse_categorical_accuracy: 0.9111 - lr: 0.0010
# Epoch 47/50
# 45/45 [==============================] - 1s 16ms/step - loss: 0.2581 - sparse_categorical_accuracy: 0.8941 - val_loss: 0.3636 - val_sparse_categorical_accuracy: 0.8153 - lr: 0.0010
# Epoch 48/50
# 45/45 [==============================] - 1s 16ms/step - loss: 0.2617 - sparse_categorical_accuracy: 0.8927 - val_loss: 0.2868 - val_sparse_categorical_accuracy: 0.8986 - lr: 0.0010
# Epoch 49/50
# 45/45 [==============================] - 1s 16ms/step - loss: 0.2545 - sparse_categorical_accuracy: 0.8944 - val_loss: 0.2929 - val_sparse_categorical_accuracy: 0.8750 - lr: 0.0010
# Epoch 50/50
# 45/45 [==============================] - 1s 18ms/step - loss: 0.2558 - sparse_categorical_accuracy: 0.8944 - val_loss: 0.2867 - val_sparse_categorical_accuracy: 0.8792 - lr: 0.0010

# %% [markdown]
# ## Plot the model's training and validation loss

# %%
metric = "sparse_categorical_accuracy"

print(f'history.params: {history.params}' )
print(f'history.history.keys(): {history.history.keys()}')

fig = plt.figure(figsize=(12,5))
fig.suptitle("title")
ax1 = fig.add_subplot()
ax2 = ax1.twinx()

ax1.plot(history.history['sparse_categorical_accuracy'], color='darkgreen', label = 'train_acc', linestyle='solid')
ax1.plot(history.history['val_sparse_categorical_accuracy'], color='green', label = 'val_acc',linestyle='--')

ax2.plot(history.history['loss'], color='firebrick', label = 'train_loss', linestyle='solid')
ax2.plot(history.history['val_loss'], color='red', label = 'val_loss',linestyle='--')

ax1.set_ylabel("accuracy")
ax2.set_ylabel("loss")

ax1.legend(loc = 'lower left')
ax2.legend(loc = 'upper left')

plt.show()
# Out:
# history.params: {'verbose': 1, 'epochs': 50, 'steps': 45}
# history.history.keys(): dict_keys(['loss', 'sparse_categorical_accuracy', 'val_loss', 'val_sparse_categorical_accuracy', 'lr'])

# %% [markdown]
# ## Evaluate model on test data

# %%
loaded_model = keras.models.load_model("best_model.h5")
test_loss, test_acc = loaded_model.evaluate(x_test, 
                                            y_test, 
                                            batch_size=batch_size,
                                            verbose=1)

print(f'=============================')
print(f'=============================')
print(f'Test accuracy {test_acc*100} and Test loss {test_loss*100}')
print(f'=============================')
print(f'=============================')
# Out:
# 21/21 [==============================] - 1s 18ms/step - loss: 0.2685 - sparse_categorical_accuracy: 0.8977
# =============================
# =============================
# Test accuracy 89.7692322731018 and Test loss 26.849812269210815
# =============================
# =============================

# %%
#Understanding your h5 model > https://www.youtube.com/watch?v=_a-UYLfF6TE
print(loaded_model.summary())
# for layer in loaded_model.layers:
    # print(layer.name)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 500, 1)]          0
#
#  conv1d (Conv1D)             (None, 500, 64)           256
#
#  batch_normalization (BatchN  (None, 500, 64)          256
#  ormalization)
#
#  re_lu (ReLU)                (None, 500, 64)           0
#
#  conv1d_1 (Conv1D)           (None, 500, 64)           12352
#
#  batch_normalization_1 (Batc  (None, 500, 64)          256
#  hNormalization)
#
#  re_lu_1 (ReLU)              (None, 500, 64)           0
#
#  conv1d_2 (Conv1D)           (None, 500, 64)           12352
#
#  batch_normalization_2 (Batc  (None, 500, 64)          256
#  hNormalization)
#
#  re_lu_2 (ReLU)              (None, 500, 64)           0
#
#  global_average_pooling1d (G  (None, 64)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 25,858
# Trainable params: 25,474
# Non-trainable params: 384
# _________________________________________________________________
# None

# %%
## Load model
predictions = loaded_model.predict(x_test)
# Out:
# 41/41 [==============================] - 1s 4ms/step

# %%
print(f'x_test.shape: {x_test.shape}, predictions.shape:  {predictions.shape}')

index = 100 # up to 9999
print('Ground truth for test timeseries: ',y_test[index])
print('Predictions for each class:\n')
for i in range(2):
    print('class:', i, ' probability: ', predictions[index][i])

# For each sample timeseries in the test dataset, select the class label with the highest probability.
predicted_labels = [np.argmax(i) for i in predictions]
print(f'len(predicted_labels): {len(predicted_labels)}')



test_pred = np.argmax(predictions, axis=1)
print(test_pred)
print(y_test)

# cm = sklearn.metrics.confusion_matrix(y_test, test_pred)
cm = sklearn.metrics.confusion_matrix(y_test, test_pred)


class_names = ['c0', 'c1']

figure = plt.figure(figsize=(5, 5))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion matrix")
plt.colorbar()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names, rotation=45)
plt.yticks(tick_marks, class_names)

# Normalize the confusion matrix.
cm = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)
# Use white text if squares are dark; otherwise black.
threshold = cm.max() / 2.

for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    color = "white" if cm[i, j] > threshold else "black"
    plt.text(j, i, cm[i, j], horizontalalignment="center", color=color)

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# x_test.shape: (1300, 500, 1), predictions.shape:  (1300, 2)
# Ground truth for test timeseries:  1
# Predictions for each class:
#
# class: 0  probability:  0.004646907
# class: 1  probability:  0.9953531
# len(predicted_labels): 1300
# [0 0 0 ... 1 0 1]
# [0 0 0 ... 1 0 1]
# Text(0.5, 55.65546539603249, 'Predicted label')

# %% [markdown]
# We can see how the training accuracy reaches almost 0.95 after 100 epochs.
# However, by observing the validation accuracy we can see how the network still needs
# training until it reaches almost 0.97 for both the validation and the training accuracy
# after 200 epochs. Beyond the 200th epoch, if we continue on training, the validation
# accuracy will start decreasing while the training accuracy will continue on increasing:
# the model starts overfitting.
